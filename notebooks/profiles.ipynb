# %%
from votekit.cvr_loaders import load_ranking_csv
from votekit.elections import IRV
from votekit.cleaning import (
    remove_cand_rank_profile,
    remove_repeat_cands_rank_profile,
    condense_rank_profile,
)
from pathlib import Path
# Out:
# /Users/bsauvage/Documents/GitHub/mggg/San-Diego-Election-Analysis/.venv/lib/python3.13/site-packages/numba/cpython/hashing.py:477: UserWarning: FNV hashing is not implemented in Numba. See PEP 456 https://www.python.org/dev/peps/pep-0456/ for rationale over not using FNV. Numba will continue to work, but hashes for built in types will be computed using siphash24. This will permit e.g. dictionaries to continue to behave as expected, however anything relying on the value of the hash opposed to hash as a derived property is likely to not work as expected.
#   warnings.warn(msg)

# %%
fp = Path("/Users/bsauvage/Desktop/mn_2013_cast_vote_record.csv")
minneapolis_profile = load_ranking_csv(fp, rank_cols=[0, 1, 2])
# Out:
# RankProfile
# Maximum ranking length: 3
# Candidates: ('JAYMIE KELLY', 'TROY BENJEGERDES', 'undervote', 'MARK V ANDERSON', 'TONY LANE', 'CHRISTOPHER ROBIN ZIMMERMAN', 'JOHN LESLIE HARTWIG', 'CAPTAIN JACK SPARROW', 'JAMES "JIMMY" L. STROUD, JR.', 'EDMUND BERNARD BRUYERE', 'GREGG A. IVERSON', 'MARK ANDREW', 'ALICIA K. BENNETT', 'JOHN CHARLES WILSON', 'CHRISTOPHER CLARK', 'RAHN V. WORKCUFF', 'OLE SAVIOR', 'JACKIE CHERRYHOMES', 'ABDUL M RAHAMAN "THE ROCK"', 'DAN COHEN', 'overvote', 'JAMES EVERETT', 'JOSHUA REA', 'STEPHANIE WOODRUFF', 'MERRILL ANDERSON', 'DON SAMUELS', 'NEAL BAXTER', 'MIKE GOULD', 'KURTIS W. HANNA', 'Rank2', 'BOB FINE', 'UWI', 'CYD GORMAN', 'BETSY HODGES', 'rank3', 'rank1', 'CAM WINTON', 'BOB "AGAIN" CARNEY JR', 'DOUG MANN', 'JEFFREY ALAN WAGNER', 'BILL KAHN')
# Candidates who received votes: ('JAYMIE KELLY', 'TROY BENJEGERDES', 'undervote', 'MARK V ANDERSON', 'TONY LANE', 'CHRISTOPHER ROBIN ZIMMERMAN', 'JOHN LESLIE HARTWIG', 'CAPTAIN JACK SPARROW', 'JAMES "JIMMY" L. STROUD, JR.', 'EDMUND BERNARD BRUYERE', 'GREGG A. IVERSON', 'MARK ANDREW', 'ALICIA K. BENNETT', 'JOHN CHARLES WILSON', 'CHRISTOPHER CLARK', 'RAHN V. WORKCUFF', 'OLE SAVIOR', 'JACKIE CHERRYHOMES', 'ABDUL M RAHAMAN "THE ROCK"', 'DAN COHEN', 'overvote', 'JAMES EVERETT', 'JOSHUA REA', 'STEPHANIE WOODRUFF', 'MERRILL ANDERSON', 'DON SAMUELS', 'NEAL BAXTER', 'MIKE GOULD', 'KURTIS W. HANNA', 'Rank2', 'BOB FINE', 'UWI', 'CYD GORMAN', 'BETSY HODGES', 'rank3', 'rank1', 'CAM WINTON', 'BOB "AGAIN" CARNEY JR', 'DOUG MANN', 'JEFFREY ALAN WAGNER', 'BILL KAHN')
# Total number of Ballot objects: 80102
# Total weight of Ballot objects: 80102.0
